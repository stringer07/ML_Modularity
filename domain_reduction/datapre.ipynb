# %%
from sklearn.model_selection import train_test_split
from datasets import Dataset, DatasetDict, load_from_disk
from transformers import T5Tokenizer, T5ForConditionalGeneration
from pathlib import Path
import torch

# %%
tokenizer = T5Tokenizer.from_pretrained("./models/t5-small")
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565

# %%
def load_pt_data(file_path):
    return torch.load(file_path)


def preprocess_function(examples):
    input_texts = [[str(num) for num in ids] for ids in examples['input_ids']]
    label_texts = [[str(num) for num in ids] for ids in examples['labels']]
    
    inputs = tokenizer(input_texts, is_split_into_words=True, padding=False, truncation=False)
    targets = tokenizer(label_texts, is_split_into_words=True, padding=False, truncation=False)
    
    model_inputs = {
        'input_ids': inputs['input_ids'],
        'attention_mask': inputs['attention_mask'],
        'labels': targets['input_ids']
    }
    return model_inputs

# %%
print("loading origin data ...")
Z_data = load_pt_data('./datasets/train/v3/Z_unified_dataset.pt')
print("loading simple data ...")
A_data = load_pt_data('./datasets/train/v3/A_unified_dataset.pt')
assert len(Z_data) == len(A_data)

A_list = A_data.tolist()
Z_list = Z_data.tolist()

# split dataset for train and test
train_Z, eval_Z, train_A, eval_A = train_test_split(
    Z_list, A_list, test_size=0.1, random_state=42
)
# Create dataset
train_dataset = Dataset.from_dict({
    'input_ids': train_Z,
    'labels': train_A
})
eval_dataset = Dataset.from_dict({
    'input_ids': eval_Z,
    'labels': eval_A
})
dataset = DatasetDict({
    'train': train_dataset,
    'eval': eval_dataset
})
tokenized_dataset = dataset.map(preprocess_function, batched=True, remove_columns=["input_ids", "labels"])

tokenized_dataset.save_to_disk("./datasets/preprocessed_data/v3")
print("preprocessed data saved to disk successfully! ")
# Out:
# loading origin data ...
# loading simple data ...
# /tmp/ipykernel_16757/2424507451.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file_path)
# Map:   0%|          | 0/900000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/900000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/100000 [00:00<?, ? examples/s]
# preprocessed data saved to disk successfully!

# %%
for i in range(10000):  
    print(f"Sample {i}: input length = {len(tokenized_dataset['train'][i+10000]['input_ids'])}")
# Out:
# Sample 0: input length = 11
# Sample 1: input length = 10
# Sample 2: input length = 12
# Sample 3: input length = 11
# Sample 4: input length = 10
# Sample 5: input length = 11
# Sample 6: input length = 9
# Sample 7: input length = 12
# Sample 8: input length = 11
# Sample 9: input length = 11
# Sample 10: input length = 10
# Sample 11: input length = 11
# Sample 12: input length = 11
# Sample 13: input length = 12
# Sample 14: input length = 10
# Sample 15: input length = 12
# Sample 16: input length = 12
# Sample 17: input length = 11
# Sample 18: input length = 9
# Sample 19: input length = 11
# Sample 20: input length = 12
# Sample 21: input length = 10
# Sample 22: input length = 11
# Sample 23: input length = 10
# Sample 24: input length = 12
# Sample 25: input length = 11
# Sample 26: input length = 10
# Sample 27: input length = 9
# Sample 28: input length = 12
# Sample 29: input length = 10
# Sample 30: input length = 11
# Sample 31: input length = 9
# Sample 32: input length = 11
# Sample 33: input length = 10
# Sample 34: input length = 9
# Sample 35: input length = 9
# Sample 36: input length = 12
# Sample 37: input length = 10
# Sample 38: input length = 10
# Sample 39: input length = 10
# Sample 40: input length = 12
# Sample 41: input length = 11
# Sample 42: input length = 11
# Sample 43: input length = 10
# Sample 44: input length = 11
# Sample 45: input length = 12
# Sample 46: input length = 11
# Sample 47: input length = 10
# Sample 48: input length = 11
# Sample 49: input length = 11
# Sample 50: input length = 10
# Sample 51: input length = 7
# Sample 52: input length = 12
# Sample 53: input length = 11
# Sample 54: input length = 9
# Sample 55: input length = 11
# Sample 56: input length = 10
# Sample 57: input length = 12
# Sample 58: input length = 9
# Sample 59: input length = 10
# Sample 60: input length = 10
# Sample 61: input length = 12
# Sample 62: input length = 11
# Sample 63: input length = 10
# Sample 64: input length = 10
# Sample 65: input length = 12
# Sample 66: input length = 12
# Sample 67: input length = 10
# Sample 68: input length = 11
# Sample 69: input length = 10
# Sample 70: input length = 11
# Sample 71: input length = 9
# Sample 72: input length = 11
# Sample 73: input length = 9
# Sample 74: input length = 11
# Sample 75: input length = 12
# Sample 76: input length = 11
# Sample 77: input length = 11
# Sample 78: input length = 12
# Sample 79: input length = 11
# Sample 80: input length = 10
# Sample 81: input length = 11
# Sample 82: input length = 10
# Sample 83: input length = 12
# Sample 84: input length = 10
# Sample 85: input length = 12
# Sample 86: input length = 11
# Sample 87: input length = 12
# Sample 88: input length = 12
# Sample 89: input length = 11
# Sample 90: input length = 8
# Sample 91: input length = 10
# Sample 92: input length = 13
# Sample 93: input length = 12
# Sample 94: input length = 11
# Sample 95: input length = 9
# Sample 96: input length = 10
# Sample 97: input length = 10
# Sample 98: input length = 9
# Sample 99: input length = 10
# Sample 100: input length = 11
# Sample 101: input length = 11
# Sample 102: input length = 9
# Sample 103: input length = 12
# Sample 104: input length = 10
# Sample 105: input length = 11
# Sample 106: input length = 11
# Sample 107: input length = 10
# Sample 108: input length = 12
# Sample 109: input length = 10
# Sample 110: input length = 12
# Sample 111: input length = 10
# Sample 112: input length = 11
# Sample 113: input length = 8
# Sample 114: input length = 11
# Sample 115: input length = 11
# Sample 116: input length = 12
# Sample 117: input length = 11
# Sample 118: input length = 10
# Sample 119: input length = 12
# Sample 120: input length = 10
# Sample 121: input length = 11
# Sample 122: input length = 12
# Sample 123: input length = 10
# Sample 124: input length = 10
# Sample 125: input length = 10
# Sample 126: input length = 10
# Sample 127: input length = 12
# Sample 128: input length = 12
# Sample 129: input length = 11
# Sample 130: input length = 11
# Sample 131: input length = 12
# Sample 132: input length = 12
# Sample 133: input length = 10
# Sample 134: input length = 11
# Sample 135: input length = 11
# Sample 136: input length = 11
# Sample 137: input length = 11
# Sample 138: input length = 10
# Sample 139: input length = 11
# Sample 140: input length = 12
# Sample 141: input length = 9
# Sample 142: input length = 11
# Sample 143: input length = 12
# Sample 144: input length = 11
# Sample 145: input length = 11
# Sample 146: input length = 10
# Sample 147: input length = 12
# Sample 148: input length = 11
# Sample 149: input length = 11
# Sample 150: input length = 9
# Sample 151: input length = 10
# Sample 152: input length = 10
# Sample 153: input length = 12
# Sample 154: input length = 10
# Sample 155: input length = 12
# Sample 156: input length = 11
# Sample 157: input length = 12
# Sample 158: input length = 11
# Sample 159: input length = 10
# Sample 160: input length = 11
# Sample 161: input length = 11
# Sample 162: input length = 10
# Sample 163: input length = 12
# Sample 164: input length = 12
# Sample 165: input length = 12
# Sample 166: input length = 9
# Sample 167: input length = 9
# Sample 168: input length = 10
# Sample 169: input length = 10
# Sample 170: input length = 10
# Sample 171: input length = 10
# Sample 172: input length = 11
# Sample 173: input length = 12
# Sample 174: input length = 11
# Sample 175: input length = 10
# Sample 176: input length = 11
# Sample 177: input length = 12
# Sample 178: input length = 12
# Sample 179: input length = 11
# Sample 180: input length = 10
# Sample 181: input length = 8
# Sample 182: input length = 11
# Sample 183: input length = 11
# Sample 184: input length = 12
# Sample 185: input length = 10
# Sample 186: input length = 10
# Sample 187: input length = 12
# Sample 188: input length = 10
# Sample 189: input length = 10
# Sample 190: input length = 11
# Sample 191: input length = 11
# Sample 192: input length = 11
# Sample 193: input length = 10
# Sample 194: input length = 12
# Sample 195: input length = 12
# Sample 196: input length = 12
# Sample 197: input length = 10
# Sample 198: input length = 10
# Sample 199: input length = 11
# Sample 200: input length = 11
# Sample 201: input length = 12
# Sample 202: input length = 10
# Sample 203: input length = 10
# Sample 204: input length = 10
# Sample 205: input length = 12
# Sample 206: input length = 11
# Sample 207: input length = 11
# Sample 208: input length = 12
# Sample 209: input length = 11
# Sample 210: input length = 11
# Sample 211: input length = 8
# Sample 212: input length = 10
# Sample 213: input length = 11
# Sample 214: input length = 9
# Sample 215: input length = 10
# Sample 216: input length = 13
# Sample 217: input length = 11
# Sample 218: input length = 12
# Sample 219: input length = 12
# Sample 220: input length = 9
# Sample 221: input length = 9
# Sample 222: input length = 12
# Sample 223: input length = 11
# Sample 224: input length = 11
# Sample 225: input length = 10
# Sample 226: input length = 11
# Sample 227: input length = 12
# Sample 228: input length = 10
# Sample 229: input length = 10
# Sample 230: input length = 10
# Sample 231: input length = 12
# Sample 232: input length = 8
# Sample 233: input length = 11
# Sample 234: input length = 10
# Sample 235: input length = 10
# Sample 236: input length = 12
# Sample 237: input length = 12
# Sample 238: input length = 11
# Sample 239: input length = 10
# Sample 240: input length = 10
# Sample 241: input length = 10
# Sample 242: input length = 11
# Sample 243: input length = 12
# Sample 244: input length = 9
# Sample 245: input length = 10
# Sample 246: input length = 12
# Sample 247: input length = 12
# Sample 248: input length = 11
# Sample 249: input length = 9
# Sample 250: input length = 10
# Sample 251: input length = 11
# Sample 252: input length = 11
# Sample 253: input length = 12
# Sample 254: input length = 11
# Sample 255: input length = 11
# Sample 256: input length = 12
# Sample 257: input length = 10
# Sample 258: input length = 11
# Sample 259: input length = 11
# Sample 260: input length = 12
# Sample 261: input length = 10
# Sample 262: input length = 12
# Sample 263: input length = 10
# Sample 264: input length = 11
# Sample 265: input length = 9
# Sample 266: input length = 11
# Sample 267: input length = 10
# Sample 268: input length = 12
# Sample 269: input length = 10
# Sample 270: input length = 13
# Sample 271: input length = 10
# Sample 272: input length = 10
# Sample 273: input length = 8
# Sample 274: input length = 11
# Sample 275: input length = 12
# Sample 276: input length = 11
# Sample 277: input length = 12
# Sample 278: input length = 10
# Sample 279: input length = 11
# Sample 280: input length = 12
# Sample 281: input length = 9
# Sample 282: input length = 9
# Sample 283: input length = 9
# Sample 284: input length = 11
# Sample 285: input length = 10
# Sample 286: input length = 12
# Sample 287: input length = 11
# Sample 288: input length = 12
# Sample 289: input length = 10
# Sample 290: input length = 11
# Sample 291: input length = 11
# Sample 292: input length = 10
# Sample 293: input length = 11
# Sample 294: input length = 10
# Sample 295: input length = 11
# Sample 296: input length = 9
# Sample 297: input length = 11
# Sample 298: input length = 12
# Sample 299: input length = 11
# Sample 300: input length = 12
# Sample 301: input length = 11
# Sample 302: input length = 11
# Sample 303: input length = 10
# Sample 304: input length = 11
# Sample 305: input length = 11
# Sample 306: input length = 13
# Sample 307: input length = 10
# Sample 308: input length = 10
# Sample 309: input length = 11
# Sample 310: input length = 9
# Sample 311: input length = 10
# Sample 312: input length = 11
# Sample 313: input length = 10
# Sample 314: input length = 11
# Sample 315: input length = 12
# Sample 316: input length = 12
# Sample 317: input length = 11
# Sample 318: input length = 11
# Sample 319: input length = 10
# Sample 320: input length = 12
# Sample 321: input length = 11
# Sample 322: input length = 10
# Sample 323: input length = 11
# Sample 324: input length = 10
# Sample 325: input length = 11
# Sample 326: input length = 12
# Sample 327: input length = 11
# Sample 328: input length = 10
# Sample 329: input length = 11
# Sample 330: input length = 10
# Sample 331: input length = 12
# Sample 332: input length = 12
# Sample 333: input length = 12
# Sample 334: input length = 10
# Sample 335: input length = 11
# Sample 336: input length = 11
# Sample 337: input length = 11
# Sample 338: input length = 11
# Sample 339: input length = 10
# Sample 340: input length = 12
# Sample 341: input length = 10
# Sample 342: input length = 9
# Sample 343: input length = 11
# Sample 344: input length = 11
# Sample 345: input length = 11
# Sample 346: input length = 11
# Sample 347: input length = 11
# Sample 348: input length = 12
# Sample 349: input length = 10
# Sample 350: input length = 11
# Sample 351: input length = 12
# Sample 352: input length = 11
# Sample 353: input length = 10
# Sample 354: input length = 8
# Sample 355: input length = 11
# Sample 356: input length = 9
# Sample 357: input length = 10
# Sample 358: input length = 10
# Sample 359: input length = 11
# Sample 360: input length = 10
# Sample 361: input length = 10
# Sample 362: input length = 12
# Sample 363: input length = 9
# Sample 364: input length = 12
# Sample 365: input length = 9
# Sample 366: input length = 11
# Sample 367: input length = 12
# Sample 368: input length = 10
# Sample 369: input length = 11
# Sample 370: input length = 10
# Sample 371: input length = 11
# Sample 372: input length = 11
# Sample 373: input length = 11
# Sample 374: input length = 11
# Sample 375: input length = 12
# Sample 376: input length = 11
# Sample 377: input length = 14
# Sample 378: input length = 10
# Sample 379: input length = 10
# Sample 380: input length = 10
# Sample 381: input length = 11
# Sample 382: input length = 11
# Sample 383: input length = 12
# Sample 384: input length = 10
# Sample 385: input length = 10
# Sample 386: input length = 12
# Sample 387: input length = 11
# Sample 388: input length = 9
# Sample 389: input length = 11
# Sample 390: input length = 11
# Sample 391: input length = 12
# Sample 392: input length = 11
# Sample 393: input length = 10
# Sample 394: input length = 10
# Sample 395: input length = 9
# Sample 396: input length = 9
# Sample 397: input length = 9
# Sample 398: input length = 11
# Sample 399: input length = 9
# Sample 400: input length = 12
# Sample 401: input length = 10
# Sample 402: input length = 11
# Sample 403: input length = 11
# Sample 404: input length = 12
# Sample 405: input length = 11
# Sample 406: input length = 11
# Sample 407: input length = 11
# Sample 408: input length = 11
# Sample 409: input length = 11
# Sample 410: input length = 11
# Sample 411: input length = 10
# Sample 412: input length = 12
# Sample 413: input length = 11
# Sample 414: input length = 12
# Sample 415: input length = 11
# Sample 416: input length = 11
# Sample 417: input length = 10
# Sample 418: input length = 10
# Sample 419: input length = 12
# Sample 420: input length = 10
# Sample 421: input length = 11
# Sample 422: input length = 12
# Sample 423: input length = 9
# Sample 424: input length = 11
# Sample 425: input length = 12
# Sample 426: input length = 12
# Sample 427: input length = 11
# Sample 428: input length = 12
# Sample 429: input length = 11
# Sample 430: input length = 10
# Sample 431: input length = 12
# Sample 432: input length = 11
# Sample 433: input length = 10
# Sample 434: input length = 10
# Sample 435: input length = 11
# Sample 436: input length = 11
# Sample 437: input length = 11
# Sample 438: input length = 10
# Sample 439: input length = 11
# Sample 440: input length = 12
# Sample 441: input length = 10
# Sample 442: input length = 9
# Sample 443: input length = 11
# Sample 444: input length = 11
# Sample 445: input length = 11
# Sample 446: input length = 11
# Sample 447: input length = 9
# Sample 448: input length = 11
# Sample 449: input length = 11
# Sample 450: input length = 12
# Sample 451: input length = 11
# Sample 452: input length = 11
# Sample 453: input length = 12
# Sample 454: input length = 11
# Sample 455: input length = 12
# Sample 456: input length = 9
# Sample 457: input length = 12
# Sample 458: input length = 12
# Sample 459: input length = 10
# Sample 460: input length = 10
# Sample 461: input length = 12
# Sample 462: input length = 10
# Sample 463: input length = 11
# Sample 464: input length = 9
# Sample 465: input length = 12
# Sample 466: input length = 10
# Sample 467: input length = 11
# Sample 468: input length = 12
# Sample 469: input length = 10
# Sample 470: input length = 10
# Sample 471: input length = 9
# Sample 472: input length = 11
# Sample 473: input length = 11
# Sample 474: input length = 12
# Sample 475: input length = 11
# Sample 476: input length = 12
# Sample 477: input length = 9
# Sample 478: input length = 10
# Sample 479: input length = 11
# Sample 480: input length = 11
# Sample 481: input length = 10
# Sample 482: input length = 12
# Sample 483: input length = 12
# Sample 484: input length = 11
# Sample 485: input length = 11
# Sample 486: input length = 11
# Sample 487: input length = 12
# Sample 488: input length = 11
# Sample 489: input length = 13
# Sample 490: input length = 12
# Sample 491: input length = 12
# Sample 492: input length = 12
# Sample 493: input length = 11
# Sample 494: input length = 10
# Sample 495: input length = 13
# Sample 496: input length = 11
# Sample 497: input length = 11
# Sample 498: input length = 10
# Sample 499: input length = 12
# Sample 500: input length = 10
# Sample 501: input length = 11
# Sample 502: input length = 10
# Sample 503: input length = 10
# Sample 504: input length = 11
# Sample 505: input length = 11
# Sample 506: input length = 10
# Sample 507: input length = 11
# Sample 508: input length = 12
# Sample 509: input length = 11
# Sample 510: input length = 11
# Sample 511: input length = 11
# Sample 512: input length = 11
# Sample 513: input length = 11
# Sample 514: input length = 10
# Sample 515: input length = 11
# Sample 516: input length = 11
# Sample 517: input length = 10
# Sample 518: input length = 11
# Sample 519: input length = 10
# Sample 520: input length = 13
# Sample 521: input length = 12
# Sample 522: input length = 9
# Sample 523: input length = 11
# Sample 524: input length = 11
# Sample 525: input length = 10
# Sample 526: input length = 10
# Sample 527: input length = 10
# Sample 528: input length = 10
# Sample 529: input length = 10
# Sample 530: input length = 11
# Sample 531: input length = 11
# Sample 532: input length = 11
# Sample 533: input length = 10
# Sample 534: input length = 11
# Sample 535: input length = 10
# Sample 536: input length = 12
# Sample 537: input length = 11
# Sample 538: input length = 10
# Sample 539: input length = 11
# Sample 540: input length = 12
# Sample 541: input length = 10
# Sample 542: input length = 11
# Sample 543: input length = 11
# Sample 544: input length = 11
# Sample 545: input length = 12
# Sample 546: input length = 10
# Sample 547: input length = 9
# Sample 548: input length = 12
# Sample 549: input length = 12
# Sample 550: input length = 12
# Sample 551: input length = 10
# Sample 552: input length = 11
# Sample 553: input length = 12
# Sample 554: input length = 10
# Sample 555: input length = 12
# Sample 556: input length = 10
# Sample 557: input length = 10
# Sample 558: input length = 11
# Sample 559: input length = 12
# Sample 560: input length = 10
# Sample 561: input length = 10
# Sample 562: input length = 11
# Sample 563: input length = 10
# Sample 564: input length = 10
# Sample 565: input length = 12
# Sample 566: input length = 11
# Sample 567: input length = 10
# Sample 568: input length = 12
# Sample 569: input length = 9
# Sample 570: input length = 11
# Sample 571: input length = 10
# Sample 572: input length = 11
# Sample 573: input length = 8
# Sample 574: input length = 10
# Sample 575: input length = 11
# Sample 576: input length = 10
# Sample 577: input length = 11
# Sample 578: input length = 10
# Sample 579: input length = 12
# Sample 580: input length = 10
# Sample 581: input length = 11
# Sample 582: input length = 11
# Sample 583: input length = 10
# Sample 584: input length = 11
# Sample 585: input length = 11
# Sample 586: input length = 10
# Sample 587: input length = 12
# Sample 588: input length = 10
# Sample 589: input length = 11
# Sample 590: input length = 10
# Sample 591: input length = 12
# Sample 592: input length = 10
# Sample 593: input length = 10
# Sample 594: input length = 11
# Sample 595: input length = 9
# Sample 596: input length = 11
# Sample 597: input length = 12
# Sample 598: input length = 10
# Sample 599: input length = 11
# Sample 600: input length = 9
# Sample 601: input length = 9
# Sample 602: input length = 12
# Sample 603: input length = 10
# Sample 604: input length = 10
# Sample 605: input length = 12
# Sample 606: input length = 11
# Sample 607: input length = 10
# Sample 608: input length = 11
# Sample 609: input length = 11
# Sample 610: input length = 12
# Sample 611: input length = 11
# Sample 612: input length = 10
# Sample 613: input length = 12
# Sample 614: input length = 10
# Sample 615: input length = 11
# Sample 616: input length = 11
# Sample 617: input length = 10
# Sample 618: input length = 10
# Sample 619: input length = 11
# Sample 620: input length = 9
# Sample 621: input length = 10
# Sample 622: input length = 11
# Sample 623: input length = 11
# Sample 624: input length = 13
# Sample 625: input length = 10
# Sample 626: input length = 12
# Sample 627: input length = 9
# Sample 628: input length = 10
# Sample 629: input length = 12
# Sample 630: input length = 10
# Sample 631: input length = 11
# Sample 632: input length = 12
# Sample 633: input length = 9
# Sample 634: input length = 11
# Sample 635: input length = 11
# Sample 636: input length = 12
# Sample 637: input length = 10
# Sample 638: input length = 10
# Sample 639: input length = 12
# Sample 640: input length = 11
# Sample 641: input length = 12
# Sample 642: input length = 11
# Sample 643: input length = 9
# Sample 644: input length = 12
# Sample 645: input length = 10
# Sample 646: input length = 12
# Sample 647: input length = 10
# Sample 648: input length = 12
# Sample 649: input length = 11
# Sample 650: input length = 12
# Sample 651: input length = 9
# Sample 652: input length = 12
# Sample 653: input length = 12
# Sample 654: input length = 12
# Sample 655: input length = 10
# Sample 656: input length = 12
# Sample 657: input length = 11
# Sample 658: input length = 10
# Sample 659: input length = 10
# Sample 660: input length = 10
# Sample 661: input length = 12
# Sample 662: input length = 9
# Sample 663: input length = 11
# Sample 664: input length = 11
# Sample 665: input length = 11
# Sample 666: input length = 12
# Sample 667: input length = 11
# Sample 668: input length = 11
# Sample 669: input length = 12
# Sample 670: input length = 11
# Sample 671: input length = 11
# Sample 672: input length = 12
# Sample 673: input length = 12
# Sample 674: input length = 12
# Sample 675: input length = 10
# Sample 676: input length = 11
# Sample 677: input length = 10
# Sample 678: input length = 11
# Sample 679: input length = 10
# Sample 680: input length = 10
# Sample 681: input length = 9
# Sample 682: input length = 12
# Sample 683: input length = 11
# Sample 684: input length = 11
# Sample 685: input length = 11
# Sample 686: input length = 12
# Sample 687: input length = 12
# Sample 688: input length = 11
# Sample 689: input length = 10
# Sample 690: input length = 12
# Sample 691: input length = 10
# Sample 692: input length = 10
# Sample 693: input length = 12
# Sample 694: input length = 10
# Sample 695: input length = 12
# Sample 696: input length = 10
# Sample 697: input length = 9
# Sample 698: input length = 11
# Sample 699: input length = 9
# Sample 700: input length = 11
# Sample 701: input length = 10
# Sample 702: input length = 11
# Sample 703: input length = 12
# Sample 704: input length = 11
# Sample 705: input length = 9
# Sample 706: input length = 12
# Sample 707: input length = 11
# Sample 708: input length = 8
# Sample 709: input length = 10
# Sample 710: input length = 9
# Sample 711: input length = 10
# Sample 712: input length = 10
# Sample 713: input length = 11
# Sample 714: input length = 11
# Sample 715: input length = 11
# Sample 716: input length = 12
# Sample 717: input length = 12
# Sample 718: input length = 12
# Sample 719: input length = 11
# Sample 720: input length = 11
# Sample 721: input length = 12
# Sample 722: input length = 10
# Sample 723: input length = 12
# Sample 724: input length = 12
# Sample 725: input length = 10
# Sample 726: input length = 8
# Sample 727: input length = 11
# Sample 728: input length = 11
# Sample 729: input length = 9
# Sample 730: input length = 11
# Sample 731: input length = 11
# Sample 732: input length = 11
# Sample 733: input length = 10
# Sample 734: input length = 12
# Sample 735: input length = 11
# Sample 736: input length = 10
# Sample 737: input length = 12
# Sample 738: input length = 10
# Sample 739: input length = 12
# Sample 740: input length = 8
# Sample 741: input length = 10
# Sample 742: input length = 10
# Sample 743: input length = 10
# Sample 744: input length = 10
# Sample 745: input length = 11
# Sample 746: input length = 11
# Sample 747: input length = 10
# Sample 748: input length = 9
# Sample 749: input length = 8
# Sample 750: input length = 9
# Sample 751: input length = 12
# Sample 752: input length = 12
# Sample 753: input length = 10
# Sample 754: input length = 11
# Sample 755: input length = 11
# Sample 756: input length = 9
# Sample 757: input length = 12
# Sample 758: input length = 10
# Sample 759: input length = 12
# Sample 760: input length = 9
# Sample 761: input length = 11
# Sample 762: input length = 11
# Sample 763: input length = 7
# Sample 764: input length = 10
# Sample 765: input length = 10
# Sample 766: input length = 12
# Sample 767: input length = 9
# Sample 768: input length = 11
# Sample 769: input length = 8
# Sample 770: input length = 10
# Sample 771: input length = 11
# Sample 772: input length = 9
# Sample 773: input length = 12
# Sample 774: input length = 11
# Sample 775: input length = 10
# Sample 776: input length = 10
# Sample 777: input length = 10
# Sample 778: input length = 12
# Sample 779: input length = 12
# Sample 780: input length = 11
# Sample 781: input length = 11
# Sample 782: input length = 11
# Sample 783: input length = 12
# Sample 784: input length = 9
# Sample 785: input length = 13
# Sample 786: input length = 12
# Sample 787: input length = 10
# Sample 788: input length = 11
# Sample 789: input length = 11
# Sample 790: input length = 12
# Sample 791: input length = 11
# Sample 792: input length = 10
# Sample 793: input length = 10
# Sample 794: input length = 11
# Sample 795: input length = 8
# Sample 796: input length = 12
# Sample 797: input length = 12
# Sample 798: input length = 10
# Sample 799: input length = 12
# Sample 800: input length = 10
# Sample 801: input length = 12
# Sample 802: input length = 12
# Sample 803: input length = 11
# Sample 804: input length = 10
# Sample 805: input length = 12
# Sample 806: input length = 12
# Sample 807: input length = 10
# Sample 808: input length = 11
# Sample 809: input length = 10
# Sample 810: input length = 12
# Sample 811: input length = 12
# Sample 812: input length = 11
# Sample 813: input length = 12
# Sample 814: input length = 11
# Sample 815: input length = 10
# Sample 816: input length = 10
# Sample 817: input length = 10
# Sample 818: input length = 11
# Sample 819: input length = 10
# Sample 820: input length = 10
# Sample 821: input length = 11
# Sample 822: input length = 10
# Sample 823: input length = 12
# Sample 824: input length = 12
# Sample 825: input length = 12
# Sample 826: input length = 10
# Sample 827: input length = 11
# Sample 828: input length = 10
# Sample 829: input length = 10
# Sample 830: input length = 11
# Sample 831: input length = 11
# Sample 832: input length = 10
# Sample 833: input length = 9
# Sample 834: input length = 11
# Sample 835: input length = 12
# Sample 836: input length = 11
# Sample 837: input length = 11
# Sample 838: input length = 12
# Sample 839: input length = 12
# Sample 840: input length = 12
# Sample 841: input length = 12
# Sample 842: input length = 11
# Sample 843: input length = 11
# Sample 844: input length = 9
# Sample 845: input length = 11
# Sample 846: input length = 9
# Sample 847: input length = 11
# Sample 848: input length = 12
# Sample 849: input length = 10
# Sample 850: input length = 12
# Sample 851: input length = 11
# Sample 852: input length = 12
# Sample 853: input length = 10
# Sample 854: input length = 10
# Sample 855: input length = 11
# Sample 856: input length = 12
# Sample 857: input length = 12
# Sample 858: input length = 11
# Sample 859: input length = 9
# Sample 860: input length = 11
# Sample 861: input length = 10
# Sample 862: input length = 11
# Sample 863: input length = 11
# Sample 864: input length = 12
# Sample 865: input length = 12
# Sample 866: input length = 10
# Sample 867: input length = 12
# Sample 868: input length = 8
# Sample 869: input length = 12
# Sample 870: input length = 11
# Sample 871: input length = 11
# Sample 872: input length = 10
# Sample 873: input length = 12
# Sample 874: input length = 11
# Sample 875: input length = 11
# Sample 876: input length = 10
# Sample 877: input length = 12
# Sample 878: input length = 12
# Sample 879: input length = 11
# Sample 880: input length = 10
# Sample 881: input length = 11
# Sample 882: input length = 11
# Sample 883: input length = 12
# Sample 884: input length = 12
# Sample 885: input length = 12
# Sample 886: input length = 11
# Sample 887: input length = 9
# Sample 888: input length = 11
# Sample 889: input length = 12
# Sample 890: input length = 11
# Sample 891: input length = 12
# Sample 892: input length = 11
# Sample 893: input length = 11
# Sample 894: input length = 11
# Sample 895: input length = 11
# Sample 896: input length = 12
# Sample 897: input length = 11
# Sample 898: input length = 11
# Sample 899: input length = 11
# Sample 900: input length = 11
# Sample 901: input length = 10
# Sample 902: input length = 10
# Sample 903: input length = 10
# Sample 904: input length = 11
# Sample 905: input length = 11
# Sample 906: input length = 11
# Sample 907: input length = 11
# Sample 908: input length = 12
# Sample 909: input length = 10
# Sample 910: input length = 8
# Sample 911: input length = 11
# Sample 912: input length = 12
# Sample 913: input length = 11
# Sample 914: input length = 10
# Sample 915: input length = 11
# Sample 916: input length = 11
# Sample 917: input length = 10
# Sample 918: input length = 11
# Sample 919: input length = 10
# Sample 920: input length = 11
# Sample 921: input length = 12
# Sample 922: input length = 11
# Sample 923: input length = 10
# Sample 924: input length = 12
# Sample 925: input length = 11
# Sample 926: input length = 12
# Sample 927: input length = 12
# Sample 928: input length = 12
# Sample 929: input length = 11
# Sample 930: input length = 11
# Sample 931: input length = 11
# Sample 932: input length = 10
# Sample 933: input length = 8
# Sample 934: input length = 11
# Sample 935: input length = 11
# Sample 936: input length = 11
# Sample 937: input length = 11
# Sample 938: input length = 8
# Sample 939: input length = 11
# Sample 940: input length = 11
# Sample 941: input length = 10
# Sample 942: input length = 10
# Sample 943: input length = 11
# Sample 944: input length = 12
# Sample 945: input length = 11
# Sample 946: input length = 11
# Sample 947: input length = 10
# Sample 948: input length = 10
# Sample 949: input length = 9
# Sample 950: input length = 10
# Sample 951: input length = 10
# Sample 952: input length = 10
# Sample 953: input length = 10
# Sample 954: input length = 9
# Sample 955: input length = 9
# Sample 956: input length = 11
# Sample 957: input length = 10
# Sample 958: input length = 11
# Sample 959: input length = 10
# Sample 960: input length = 12
# Sample 961: input length = 10
# Sample 962: input length = 10
# Sample 963: input length = 11
# Sample 964: input length = 12
# Sample 965: input length = 9
# Sample 966: input length = 12
# Sample 967: input length = 12
# Sample 968: input length = 11
# Sample 969: input length = 11
# Sample 970: input length = 10
# Sample 971: input length = 11
# Sample 972: input length = 12
# Sample 973: input length = 12
# Sample 974: input length = 11
# Sample 975: input length = 8
# Sample 976: input length = 11
# Sample 977: input length = 10
# Sample 978: input length = 10
# Sample 979: input length = 11
# Sample 980: input length = 12
# Sample 981: input length = 11
# Sample 982: input length = 10
# Sample 983: input length = 8
# Sample 984: input length = 12
# Sample 985: input length = 10
# Sample 986: input length = 9
# Sample 987: input length = 9
# Sample 988: input length = 10
# Sample 989: input length = 11
# Sample 990: input length = 10
# Sample 991: input length = 10
# Sample 992: input length = 11
# Sample 993: input length = 12
# Sample 994: input length = 10
# Sample 995: input length = 11
# Sample 996: input length = 8
# Sample 997: input length = 10
# Sample 998: input length = 10
# Sample 999: input length = 9
# Sample 1000: input length = 12
# Sample 1001: input length = 10
# Sample 1002: input length = 12
# Sample 1003: input length = 11
# Sample 1004: input length = 12
# Sample 1005: input length = 11
# Sample 1006: input length = 10
# Sample 1007: input length = 11
# Sample 1008: input length = 11
# Sample 1009: input length = 12
# Sample 1010: input length = 11
# Sample 1011: input length = 12
# Sample 1012: input length = 9
# Sample 1013: input length = 10
# Sample 1014: input length = 9
# Sample 1015: input length = 11
# Sample 1016: input length = 8
# Sample 1017: input length = 12
# Sample 1018: input length = 11
# Sample 1019: input length = 10
# Sample 1020: input length = 11
# Sample 1021: input length = 11
# Sample 1022: input length = 11
# Sample 1023: input length = 11
# Sample 1024: input length = 9
# Sample 1025: input length = 12
# Sample 1026: input length = 10
# Sample 1027: input length = 11
# Sample 1028: input length = 12
# Sample 1029: input length = 10
# Sample 1030: input length = 9
# Sample 1031: input length = 11
# Sample 1032: input length = 11
# Sample 1033: input length = 10
# Sample 1034: input length = 11
# Sample 1035: input length = 12
# Sample 1036: input length = 11
# Sample 1037: input length = 11
# Sample 1038: input length = 12
# Sample 1039: input length = 10
# Sample 1040: input length = 10
# Sample 1041: input length = 10
# Sample 1042: input length = 11
# Sample 1043: input length = 11
# Sample 1044: input length = 12
# Sample 1045: input length = 10
# Sample 1046: input length = 11
# Sample 1047: input length = 12
# Sample 1048: input length = 12
# Sample 1049: input length = 11
# Sample 1050: input length = 9
# Sample 1051: input length = 10
# Sample 1052: input length = 12
# Sample 1053: input length = 10
# Sample 1054: input length = 11
# Sample 1055: input length = 10
# Sample 1056: input length = 10
# Sample 1057: input length = 11
# Sample 1058: input length = 10
# Sample 1059: input length = 11
# Sample 1060: input length = 11
# Sample 1061: input length = 9
# Sample 1062: input length = 10
# Sample 1063: input length = 10
# Sample 1064: input length = 12
# Sample 1065: input length = 11
# Sample 1066: input length = 11
# Sample 1067: input length = 11
# Sample 1068: input length = 11
# Sample 1069: input length = 11
# Sample 1070: input length = 10
# Sample 1071: input length = 12
# Sample 1072: input length = 11
# Sample 1073: input length = 10
# Sample 1074: input length = 13
# Sample 1075: input length = 9
# Sample 1076: input length = 11
# Sample 1077: input length = 10
# Sample 1078: input length = 12
# Sample 1079: input length = 11
# Sample 1080: input length = 10
# Sample 1081: input length = 10
# Sample 1082: input length = 11
# Sample 1083: input length = 10
# Sample 1084: input length = 11
# Sample 1085: input length = 11
# Sample 1086: input length = 9
# Sample 1087: input length = 10
# Sample 1088: input length = 9
# Sample 1089: input length = 12
# Sample 1090: input length = 10
# Sample 1091: input length = 10
# Sample 1092: input length = 9
# Sample 1093: input length = 12
# Sample 1094: input length = 9
# Sample 1095: input length = 11
# Sample 1096: input length = 11
# Sample 1097: input length = 9
# Sample 1098: input length = 9
# Sample 1099: input length = 10
# Sample 1100: input length = 10
# Sample 1101: input length = 11
# Sample 1102: input length = 12
# Sample 1103: input length = 10
# Sample 1104: input length = 11
# Sample 1105: input length = 12
# Sample 1106: input length = 9
# Sample 1107: input length = 10
# Sample 1108: input length = 12
# Sample 1109: input length = 11
# Sample 1110: input length = 11
# Sample 1111: input length = 10
# Sample 1112: input length = 12
# Sample 1113: input length = 12
# Sample 1114: input length = 11
# Sample 1115: input length = 11
# Sample 1116: input length = 9
# Sample 1117: input length = 11
# Sample 1118: input length = 10
# Sample 1119: input length = 9
# Sample 1120: input length = 10
# Sample 1121: input length = 10
# Sample 1122: input length = 11
# Sample 1123: input length = 11
# Sample 1124: input length = 11
# Sample 1125: input length = 12
# Sample 1126: input length = 11
# Sample 1127: input length = 10
# Sample 1128: input length = 11
# Sample 1129: input length = 10
# Sample 1130: input length = 11
# Sample 1131: input length = 11
# Sample 1132: input length = 12
# Sample 1133: input length = 9
# Sample 1134: input length = 12
# Sample 1135: input length = 12
# Sample 1136: input length = 12
# Sample 1137: input length = 9
# Sample 1138: input length = 11
# Sample 1139: input length = 12
# Sample 1140: input length = 10
# Sample 1141: input length = 12
# Sample 1142: input length = 8
# Sample 1143: input length = 9
# Sample 1144: input length = 11
# Sample 1145: input length = 10
# Sample 1146: input length = 12
# Sample 1147: input length = 11
# Sample 1148: input length = 11
# Sample 1149: input length = 11
# Sample 1150: input length = 9
# Sample 1151: input length = 11
# Sample 1152: input length = 12
# Sample 1153: input length = 11
# Sample 1154: input length = 11
# Sample 1155: input length = 11
# Sample 1156: input length = 9
# Sample 1157: input length = 10
# Sample 1158: input length = 12
# Sample 1159: input length = 12
# Sample 1160: input length = 11
# Sample 1161: input length = 11
# Sample 1162: input length = 10
# Sample 1163: input length = 10
# Sample 1164: input length = 11
# Sample 1165: input length = 11
# Sample 1166: input length = 10
# Sample 1167: input length = 10
# Sample 1168: input length = 12
# Sample 1169: input length = 11
# Sample 1170: input length = 11
# Sample 1171: input length = 11
# Sample 1172: input length = 11
# Sample 1173: input length = 10
# Sample 1174: input length = 12
# Sample 1175: input length = 12
# Sample 1176: input length = 11
# Sample 1177: input length = 10
# Sample 1178: input length = 12
# Sample 1179: input length = 10
# Sample 1180: input length = 12
# Sample 1181: input length = 11
# Sample 1182: input length = 9
# Sample 1183: input length = 12
# Sample 1184: input length = 12
# Sample 1185: input length = 12
# Sample 1186: input length = 11
# Sample 1187: input length = 9
# Sample 1188: input length = 9
# Sample 1189: input length = 12
# Sample 1190: input length = 10
# Sample 1191: input length = 11
# Sample 1192: input length = 12
# Sample 1193: input length = 12
# Sample 1194: input length = 12
# Sample 1195: input length = 8
# Sample 1196: input length = 11
# Sample 1197: input length = 12
# Sample 1198: input length = 12
# Sample 1199: input length = 11
# Sample 1200: input length = 11
# Sample 1201: input length = 12
# Sample 1202: input length = 10
# Sample 1203: input length = 11
# Sample 1204: input length = 11
# Sample 1205: input length = 12
# Sample 1206: input length = 12
# Sample 1207: input length = 11
# Sample 1208: input length = 11
# Sample 1209: input length = 11
# Sample 1210: input length = 12
# Sample 1211: input length = 10
# Sample 1212: input length = 12
# Sample 1213: input length = 10
# Sample 1214: input length = 12
# Sample 1215: input length = 11
# Sample 1216: input length = 11
# Sample 1217: input length = 8
# Sample 1218: input length = 12
# Sample 1219: input length = 12
# Sample 1220: input length = 13
# Sample 1221: input length = 10
# Sample 1222: input length = 12
# Sample 1223: input length = 11
# Sample 1224: input length = 9
# Sample 1225: input length = 11
# Sample 1226: input length = 12
# Sample 1227: input length = 12
# Sample 1228: input length = 10
# Sample 1229: input length = 10
# Sample 1230: input length = 10
# Sample 1231: input length = 10
# Sample 1232: input length = 10
# Sample 1233: input length = 11
# Sample 1234: input length = 8
# Sample 1235: input length = 11
# Sample 1236: input length = 12
# Sample 1237: input length = 10
# Sample 1238: input length = 11
# Sample 1239: input length = 11
# Sample 1240: input length = 11
# Sample 1241: input length = 10
# Sample 1242: input length = 12
# Sample 1243: input length = 11
# Sample 1244: input length = 11
# Sample 1245: input length = 12
# Sample 1246: input length = 11
# Sample 1247: input length = 10
# Sample 1248: input length = 11
# Sample 1249: input length = 11
# Sample 1250: input length = 11
# Sample 1251: input length = 11
# Sample 1252: input length = 12
# Sample 1253: input length = 9
# Sample 1254: input length = 11
# Sample 1255: input length = 11
# Sample 1256: input length = 10
# Sample 1257: input length = 10
# Sample 1258: input length = 11
# Sample 1259: input length = 10
# Sample 1260: input length = 11
# Sample 1261: input length = 12
# Sample 1262: input length = 10
# Sample 1263: input length = 9
# Sample 1264: input length = 9
# Sample 1265: input length = 11
# Sample 1266: input length = 10
# Sample 1267: input length = 12
# Sample 1268: input length = 12
# Sample 1269: input length = 11
# Sample 1270: input length = 10
# Sample 1271: input length = 12
# Sample 1272: input length = 11
# Sample 1273: input length = 11
# Sample 1274: input length = 11
# Sample 1275: input length = 13
# Sample 1276: input length = 9
# Sample 1277: input length = 11
# Sample 1278: input length = 9
# Sample 1279: input length = 10
# Sample 1280: input length = 9
# Sample 1281: input length = 10
# Sample 1282: input length = 10
# Sample 1283: input length = 11
# Sample 1284: input length = 10
# Sample 1285: input length = 11
# Sample 1286: input length = 11
# Sample 1287: input length = 10
# Sample 1288: input length = 11
# Sample 1289: input length = 9
# Sample 1290: input length = 11
# Sample 1291: input length = 11
# Sample 1292: input length = 12
# Sample 1293: input length = 12
# Sample 1294: input length = 11
# Sample 1295: input length = 12
# Sample 1296: input length = 12
# Sample 1297: input length = 9
# Sample 1298: input length = 10
# Sample 1299: input length = 11
# Sample 1300: input length = 9
# Sample 1301: input length = 11
# Sample 1302: input length = 10
# Sample 1303: input length = 12
# Sample 1304: input length = 11
# Sample 1305: input length = 11
# Sample 1306: input length = 12
# Sample 1307: input length = 12
# Sample 1308: input length = 11
# Sample 1309: input length = 9
# Sample 1310: input length = 12
# Sample 1311: input length = 7
# Sample 1312: input length = 11
# Sample 1313: input length = 9
# Sample 1314: input length = 11
# Sample 1315: input length = 11
# Sample 1316: input length = 11
# Sample 1317: input length = 10
# Sample 1318: input length = 12
# Sample 1319: input length = 9
# Sample 1320: input length = 11
# Sample 1321: input length = 10
# Sample 1322: input length = 10
# Sample 1323: input length = 10
# Sample 1324: input length = 10
# Sample 1325: input length = 11
# Sample 1326: input length = 11
# Sample 1327: input length = 12
# Sample 1328: input length = 10
# Sample 1329: input length = 11
# Sample 1330: input length = 11
# Sample 1331: input length = 11
# Sample 1332: input length = 10
# Sample 1333: input length = 10
# Sample 1334: input length = 12
# Sample 1335: input length = 11
# Sample 1336: input length = 10
# Sample 1337: input length = 9
# Sample 1338: input length = 9
# Sample 1339: input length = 10
# Sample 1340: input length = 11
# Sample 1341: input length = 14
# Sample 1342: input length = 9
# Sample 1343: input length = 9
# Sample 1344: input length = 11
# Sample 1345: input length = 11
# Sample 1346: input length = 11
# Sample 1347: input length = 12
# Sample 1348: input length = 12
# Sample 1349: input length = 9
# Sample 1350: input length = 11
# Sample 1351: input length = 11
# Sample 1352: input length = 12
# Sample 1353: input length = 12
# Sample 1354: input length = 9
# Sample 1355: input length = 10
# Sample 1356: input length = 10
# Sample 1357: input length = 11
# Sample 1358: input length = 11
# Sample 1359: input length = 12
# Sample 1360: input length = 11
# Sample 1361: input length = 10
# Sample 1362: input length = 9
# Sample 1363: input length = 11
# Sample 1364: input length = 11
# Sample 1365: input length = 10
# Sample 1366: input length = 10
# Sample 1367: input length = 11
# Sample 1368: input length = 12
# Sample 1369: input length = 11
# Sample 1370: input length = 12
# Sample 1371: input length = 10
# Sample 1372: input length = 10
# Sample 1373: input length = 12
# Sample 1374: input length = 11
# Sample 1375: input length = 11
# Sample 1376: input length = 10
# Sample 1377: input length = 9
# Sample 1378: input length = 11
# Sample 1379: input length = 11
# Sample 1380: input length = 12
# Sample 1381: input length = 11
# Sample 1382: input length = 10
# Sample 1383: input length = 10
# Sample 1384: input length = 11
# Sample 1385: input length = 11
# Sample 1386: input length = 12
# Sample 1387: input length = 10
# Sample 1388: input length = 12
# Sample 1389: input length = 10
# Sample 1390: input length = 11
# Sample 1391: input length = 11
# Sample 1392: input length = 10
# Sample 1393: input length = 11
# Sample 1394: input length = 10
# Sample 1395: input length = 10
# Sample 1396: input length = 11
# Sample 1397: input length = 9
# Sample 1398: input length = 13
# Sample 1399: input length = 11
# Sample 1400: input length = 11
# Sample 1401: input length = 10
# Sample 1402: input length = 11
# Sample 1403: input length = 11
# Sample 1404: input length = 11
# Sample 1405: input length = 10
# Sample 1406: input length = 11
# Sample 1407: input length = 12
# Sample 1408: input length = 11
# Sample 1409: input length = 10
# Sample 1410: input length = 11
# Sample 1411: input length = 10
# Sample 1412: input length = 13
# Sample 1413: input length = 10
# Sample 1414: input length = 12
# Sample 1415: input length = 11
# Sample 1416: input length = 12
# Sample 1417: input length = 12
# Sample 1418: input length = 11
# Sample 1419: input length = 11
# Sample 1420: input length = 11
# Sample 1421: input length = 9
# Sample 1422: input length = 11
# Sample 1423: input length = 11
# Sample 1424: input length = 10
# Sample 1425: input length = 8
# Sample 1426: input length = 11
# Sample 1427: input length = 9
# Sample 1428: input length = 11
# Sample 1429: input length = 13
# Sample 1430: input length = 11
# Sample 1431: input length = 10
# Sample 1432: input length = 13
# Sample 1433: input length = 10
# Sample 1434: input length = 10
# Sample 1435: input length = 11
# Sample 1436: input length = 12
# Sample 1437: input length = 10
# Sample 1438: input length = 10
# Sample 1439: input length = 12
# Sample 1440: input length = 12
# Sample 1441: input length = 11
# Sample 1442: input length = 10
# Sample 1443: input length = 11
# Sample 1444: input length = 12
# Sample 1445: input length = 10
# Sample 1446: input length = 9
# Sample 1447: input length = 10
# Sample 1448: input length = 12
# Sample 1449: input length = 10
# Sample 1450: input length = 11
# Sample 1451: input length = 9
# Sample 1452: input length = 8
# Sample 1453: input length = 10
# Sample 1454: input length = 10
# Sample 1455: input length = 11
# Sample 1456: input length = 11
# Sample 1457: input length = 11
# Sample 1458: input length = 11
# Sample 1459: input length = 9
# Sample 1460: input length = 8
# Sample 1461: input length = 11
# Sample 1462: input length = 10
# Sample 1463: input length = 10
# Sample 1464: input length = 13
# Sample 1465: input length = 11
# Sample 1466: input length = 9
# Sample 1467: input length = 10
# Sample 1468: input length = 12
# Sample 1469: input length = 9
# Sample 1470: input length = 11
# Sample 1471: input length = 10
# Sample 1472: input length = 12
# Sample 1473: input length = 11
# Sample 1474: input length = 12
# Sample 1475: input length = 11
# Sample 1476: input length = 11
# Sample 1477: input length = 10
# Sample 1478: input length = 10
# Sample 1479: input length = 11
# Sample 1480: input length = 10
# Sample 1481: input length = 10
# Sample 1482: input length = 10
# Sample 1483: input length = 11
# Sample 1484: input length = 11
# Sample 1485: input length = 12
# Sample 1486: input length = 11
# Sample 1487: input length = 11
# Sample 1488: input length = 10
# Sample 1489: input length = 10
# Sample 1490: input length = 10
# Sample 1491: input length = 11
# Sample 1492: input length = 11
# Sample 1493: input length = 9
# Sample 1494: input length = 12
# Sample 1495: input length = 10
# Sample 1496: input length = 11
# Sample 1497: input length = 12
# Sample 1498: input length = 11
# Sample 1499: input length = 11
# Sample 1500: input length = 12
# Sample 1501: input length = 12
# Sample 1502: input length = 12
# Sample 1503: input length = 11
# Sample 1504: input length = 13
# Sample 1505: input length = 12
# Sample 1506: input length = 12
# Sample 1507: input length = 12
# Sample 1508: input length = 10
# Sample 1509: input length = 12
# Sample 1510: input length = 12
# Sample 1511: input length = 11
# Sample 1512: input length = 11
# Sample 1513: input length = 11
# Sample 1514: input length = 11
# Sample 1515: input length = 9
# Sample 1516: input length = 8
# Sample 1517: input length = 10
# Sample 1518: input length = 11
# Sample 1519: input length = 11
# Sample 1520: input length = 11
# Sample 1521: input length = 11
# Sample 1522: input length = 10
# Sample 1523: input length = 12
# Sample 1524: input length = 12
# Sample 1525: input length = 12
# Sample 1526: input length = 10
# Sample 1527: input length = 11
# Sample 1528: input length = 11
# Sample 1529: input length = 9
# Sample 1530: input length = 11
# Sample 1531: input length = 11
# Sample 1532: input length = 11
# Sample 1533: input length = 9
# Sample 1534: input length = 11
# Sample 1535: input length = 12
# Sample 1536: input length = 10
# Sample 1537: input length = 12
# Sample 1538: input length = 10
# Sample 1539: input length = 11
# Sample 1540: input length = 12
# Sample 1541: input length = 10
# Sample 1542: input length = 9
# Sample 1543: input length = 10
# Sample 1544: input length = 12
# Sample 1545: input length = 12
# Sample 1546: input length = 12
# Sample 1547: input length = 10
# Sample 1548: input length = 12
# Sample 1549: input length = 12
# Sample 1550: input length = 12
# Sample 1551: input length = 11
# Sample 1552: input length = 11
# Sample 1553: input length = 12
# Sample 1554: input length = 11
# Sample 1555: input length = 9
# Sample 1556: input length = 11
# Sample 1557: input length = 10
# Sample 1558: input length = 12
# Sample 1559: input length = 12
# Sample 1560: input length = 9
# Sample 1561: input length = 13
# Sample 1562: input length = 12
# Sample 1563: input length = 8
# Sample 1564: input length = 10
# Sample 1565: input length = 10
# Sample 1566: input length = 10
# Sample 1567: input length = 10
# Sample 1568: input length = 7
# Sample 1569: input length = 11
# Sample 1570: input length = 11
# Sample 1571: input length = 10
# Sample 1572: input length = 11
# Sample 1573: input length = 10
# Sample 1574: input length = 11
# Sample 1575: input length = 12
# Sample 1576: input length = 11
# Sample 1577: input length = 12
# Sample 1578: input length = 11
# Sample 1579: input length = 11
# Sample 1580: input length = 11
# Sample 1581: input length = 9
# Sample 1582: input length = 12
# Sample 1583: input length = 10
# Sample 1584: input length = 11
# Sample 1585: input length = 10
# Sample 1586: input length = 11
# Sample 1587: input length = 12
# Sample 1588: input length = 11
# ...
# Sample 9482: input length = 9
# Sample 9483: input length = 12
# Sample 9484: input length = 12
# Sample 9485: input length = 11
# Sample 9486: input length = 11
# Sample 9487: input length = 12
# Sample 9488: input length = 11
# Sample 9489: input length = 11
# Sample 9490: input length = 11
# Sample 9491: input length = 10
# Sample 9492: input length = 11
# Sample 9493: input length = 11
# Sample 9494: input length = 11
# Sample 9495: input length = 9
# Sample 9496: input length = 8
# Sample 9497: input length = 8
# Sample 9498: input length = 10
# Sample 9499: input length = 11
# Sample 9500: input length = 10
# Sample 9501: input length = 10
# Sample 9502: input length = 10
# Sample 9503: input length = 9
# Sample 9504: input length = 12
# Sample 9505: input length = 11
# Sample 9506: input length = 9
# Sample 9507: input length = 10
# Sample 9508: input length = 10
# Sample 9509: input length = 12
# Sample 9510: input length = 12
# Sample 9511: input length = 12
# Sample 9512: input length = 11
# Sample 9513: input length = 12
# Sample 9514: input length = 11
# Sample 9515: input length = 11
# Sample 9516: input length = 11
# Sample 9517: input length = 10
# Sample 9518: input length = 10
# Sample 9519: input length = 11
# Sample 9520: input length = 11
# Sample 9521: input length = 11
# Sample 9522: input length = 11
# Sample 9523: input length = 10
# Sample 9524: input length = 11
# Sample 9525: input length = 11
# Sample 9526: input length = 12
# Sample 9527: input length = 11
# Sample 9528: input length = 9
# Sample 9529: input length = 11
# Sample 9530: input length = 11
# Sample 9531: input length = 11
# Sample 9532: input length = 11
# Sample 9533: input length = 11
# Sample 9534: input length = 11
# Sample 9535: input length = 11
# Sample 9536: input length = 10
# Sample 9537: input length = 12
# Sample 9538: input length = 9
# Sample 9539: input length = 11
# Sample 9540: input length = 11
# Sample 9541: input length = 12
# Sample 9542: input length = 10
# Sample 9543: input length = 11
# Sample 9544: input length = 11
# Sample 9545: input length = 12
# Sample 9546: input length = 11
# Sample 9547: input length = 9
# Sample 9548: input length = 11
# Sample 9549: input length = 11
# Sample 9550: input length = 9
# Sample 9551: input length = 12
# Sample 9552: input length = 9
# Sample 9553: input length = 10
# Sample 9554: input length = 11
# Sample 9555: input length = 10
# Sample 9556: input length = 11
# Sample 9557: input length = 11
# Sample 9558: input length = 12
# Sample 9559: input length = 11
# Sample 9560: input length = 12
# Sample 9561: input length = 11
# Sample 9562: input length = 12
# Sample 9563: input length = 11
# Sample 9564: input length = 10
# Sample 9565: input length = 12
# Sample 9566: input length = 11
# Sample 9567: input length = 10
# Sample 9568: input length = 9
# Sample 9569: input length = 11
# Sample 9570: input length = 10
# Sample 9571: input length = 11
# Sample 9572: input length = 10
# Sample 9573: input length = 12
# Sample 9574: input length = 10
# Sample 9575: input length = 9
# Sample 9576: input length = 10
# Sample 9577: input length = 9
# Sample 9578: input length = 11
# Sample 9579: input length = 11
# Sample 9580: input length = 12
# Sample 9581: input length = 12
# Sample 9582: input length = 11
# Sample 9583: input length = 11
# Sample 9584: input length = 12
# Sample 9585: input length = 12
# Sample 9586: input length = 12
# Sample 9587: input length = 12
# Sample 9588: input length = 12
# Sample 9589: input length = 10
# Sample 9590: input length = 11
# Sample 9591: input length = 8
# Sample 9592: input length = 11
# Sample 9593: input length = 10
# Sample 9594: input length = 11
# Sample 9595: input length = 12
# Sample 9596: input length = 11
# Sample 9597: input length = 9
# Sample 9598: input length = 11
# Sample 9599: input length = 11
# Sample 9600: input length = 11
# Sample 9601: input length = 9
# Sample 9602: input length = 12
# Sample 9603: input length = 11
# Sample 9604: input length = 10
# Sample 9605: input length = 9
# Sample 9606: input length = 9
# Sample 9607: input length = 12
# Sample 9608: input length = 12
# Sample 9609: input length = 11
# Sample 9610: input length = 11
# Sample 9611: input length = 10
# Sample 9612: input length = 10
# Sample 9613: input length = 8
# Sample 9614: input length = 10
# Sample 9615: input length = 12
# Sample 9616: input length = 12
# Sample 9617: input length = 13
# Sample 9618: input length = 12
# Sample 9619: input length = 8
# Sample 9620: input length = 10
# Sample 9621: input length = 10
# Sample 9622: input length = 10
# Sample 9623: input length = 11
# Sample 9624: input length = 11
# Sample 9625: input length = 10
# Sample 9626: input length = 11
# Sample 9627: input length = 9
# Sample 9628: input length = 11
# Sample 9629: input length = 10
# Sample 9630: input length = 10
# Sample 9631: input length = 11
# Sample 9632: input length = 11
# Sample 9633: input length = 11
# Sample 9634: input length = 9
# Sample 9635: input length = 9
# Sample 9636: input length = 10
# Sample 9637: input length = 11
# Sample 9638: input length = 9
# Sample 9639: input length = 11
# Sample 9640: input length = 10
# Sample 9641: input length = 11
# Sample 9642: input length = 10
# Sample 9643: input length = 9
# Sample 9644: input length = 12
# Sample 9645: input length = 11
# Sample 9646: input length = 11
# Sample 9647: input length = 11
# Sample 9648: input length = 8
# Sample 9649: input length = 12
# Sample 9650: input length = 11
# Sample 9651: input length = 10
# Sample 9652: input length = 12
# Sample 9653: input length = 9
# Sample 9654: input length = 12
# Sample 9655: input length = 11
# Sample 9656: input length = 11
# Sample 9657: input length = 12
# Sample 9658: input length = 10
# Sample 9659: input length = 10
# Sample 9660: input length = 11
# Sample 9661: input length = 9
# Sample 9662: input length = 10
# Sample 9663: input length = 11
# Sample 9664: input length = 10
# Sample 9665: input length = 12
# Sample 9666: input length = 11
# Sample 9667: input length = 11
# Sample 9668: input length = 11
# Sample 9669: input length = 11
# Sample 9670: input length = 11
# Sample 9671: input length = 11
# Sample 9672: input length = 9
# Sample 9673: input length = 11
# Sample 9674: input length = 10
# Sample 9675: input length = 10
# Sample 9676: input length = 9
# Sample 9677: input length = 10
# Sample 9678: input length = 11
# Sample 9679: input length = 11
# Sample 9680: input length = 10
# Sample 9681: input length = 11
# Sample 9682: input length = 10
# Sample 9683: input length = 10
# Sample 9684: input length = 11
# Sample 9685: input length = 11
# Sample 9686: input length = 12
# Sample 9687: input length = 11
# Sample 9688: input length = 12
# Sample 9689: input length = 10
# Sample 9690: input length = 11
# Sample 9691: input length = 10
# Sample 9692: input length = 12
# Sample 9693: input length = 11
# Sample 9694: input length = 11
# Sample 9695: input length = 11
# Sample 9696: input length = 11
# Sample 9697: input length = 10
# Sample 9698: input length = 12
# Sample 9699: input length = 13
# Sample 9700: input length = 10
# Sample 9701: input length = 10
# Sample 9702: input length = 10
# Sample 9703: input length = 11
# Sample 9704: input length = 12
# Sample 9705: input length = 9
# Sample 9706: input length = 12
# Sample 9707: input length = 9
# Sample 9708: input length = 11
# Sample 9709: input length = 12
# Sample 9710: input length = 9
# Sample 9711: input length = 12
# Sample 9712: input length = 12
# Sample 9713: input length = 12
# Sample 9714: input length = 8
# Sample 9715: input length = 9
# Sample 9716: input length = 11
# Sample 9717: input length = 12
# Sample 9718: input length = 12
# Sample 9719: input length = 12
# Sample 9720: input length = 9
# Sample 9721: input length = 9
# Sample 9722: input length = 10
# Sample 9723: input length = 11
# Sample 9724: input length = 12
# Sample 9725: input length = 9
# Sample 9726: input length = 11
# Sample 9727: input length = 10
# Sample 9728: input length = 11
# Sample 9729: input length = 11
# Sample 9730: input length = 11
# Sample 9731: input length = 12
# Sample 9732: input length = 11
# Sample 9733: input length = 11
# Sample 9734: input length = 11
# Sample 9735: input length = 10
# Sample 9736: input length = 11
# Sample 9737: input length = 10
# Sample 9738: input length = 10
# Sample 9739: input length = 10
# Sample 9740: input length = 11
# Sample 9741: input length = 10
# Sample 9742: input length = 11
# Sample 9743: input length = 9
# Sample 9744: input length = 13
# Sample 9745: input length = 11
# Sample 9746: input length = 12
# Sample 9747: input length = 12
# Sample 9748: input length = 11
# Sample 9749: input length = 11
# Sample 9750: input length = 12
# Sample 9751: input length = 9
# Sample 9752: input length = 9
# Sample 9753: input length = 12
# Sample 9754: input length = 10
# Sample 9755: input length = 11
# Sample 9756: input length = 12
# Sample 9757: input length = 9
# Sample 9758: input length = 12
# Sample 9759: input length = 11
# Sample 9760: input length = 13
# Sample 9761: input length = 9
# Sample 9762: input length = 12
# Sample 9763: input length = 11
# Sample 9764: input length = 12
# Sample 9765: input length = 10
# Sample 9766: input length = 11
# Sample 9767: input length = 11
# Sample 9768: input length = 11
# Sample 9769: input length = 11
# Sample 9770: input length = 11
# Sample 9771: input length = 12
# Sample 9772: input length = 11
# Sample 9773: input length = 11
# Sample 9774: input length = 11
# Sample 9775: input length = 10
# Sample 9776: input length = 12
# Sample 9777: input length = 10
# Sample 9778: input length = 12
# Sample 9779: input length = 11
# Sample 9780: input length = 12
# Sample 9781: input length = 10
# Sample 9782: input length = 9
# Sample 9783: input length = 11
# Sample 9784: input length = 12
# Sample 9785: input length = 12
# Sample 9786: input length = 10
# Sample 9787: input length = 12
# Sample 9788: input length = 11
# Sample 9789: input length = 11
# Sample 9790: input length = 11
# Sample 9791: input length = 10
# Sample 9792: input length = 11
# Sample 9793: input length = 11
# Sample 9794: input length = 10
# Sample 9795: input length = 11
# Sample 9796: input length = 9
# Sample 9797: input length = 12
# Sample 9798: input length = 11
# Sample 9799: input length = 11
# Sample 9800: input length = 10
# Sample 9801: input length = 11
# Sample 9802: input length = 11
# Sample 9803: input length = 11
# Sample 9804: input length = 12
# Sample 9805: input length = 12
# Sample 9806: input length = 12
# Sample 9807: input length = 12
# Sample 9808: input length = 10
# Sample 9809: input length = 12
# Sample 9810: input length = 12
# Sample 9811: input length = 11
# Sample 9812: input length = 11
# Sample 9813: input length = 11
# Sample 9814: input length = 10
# Sample 9815: input length = 8
# Sample 9816: input length = 10
# Sample 9817: input length = 12
# Sample 9818: input length = 13
# Sample 9819: input length = 11
# Sample 9820: input length = 12
# Sample 9821: input length = 12
# Sample 9822: input length = 10
# Sample 9823: input length = 10
# Sample 9824: input length = 9
# Sample 9825: input length = 11
# Sample 9826: input length = 10
# Sample 9827: input length = 11
# Sample 9828: input length = 11
# Sample 9829: input length = 10
# Sample 9830: input length = 11
# Sample 9831: input length = 11
# Sample 9832: input length = 10
# Sample 9833: input length = 10
# Sample 9834: input length = 11
# Sample 9835: input length = 11
# Sample 9836: input length = 11
# Sample 9837: input length = 10
# Sample 9838: input length = 12
# Sample 9839: input length = 11
# Sample 9840: input length = 10
# Sample 9841: input length = 10
# Sample 9842: input length = 11
# Sample 9843: input length = 10
# Sample 9844: input length = 9
# Sample 9845: input length = 12
# Sample 9846: input length = 11
# Sample 9847: input length = 12
# Sample 9848: input length = 11
# Sample 9849: input length = 12
# Sample 9850: input length = 11
# Sample 9851: input length = 12
# Sample 9852: input length = 12
# Sample 9853: input length = 11
# Sample 9854: input length = 10
# Sample 9855: input length = 11
# Sample 9856: input length = 12
# Sample 9857: input length = 12
# Sample 9858: input length = 12
# Sample 9859: input length = 9
# Sample 9860: input length = 10
# Sample 9861: input length = 10
# Sample 9862: input length = 11
# Sample 9863: input length = 10
# Sample 9864: input length = 11
# Sample 9865: input length = 11
# Sample 9866: input length = 11
# Sample 9867: input length = 12
# Sample 9868: input length = 9
# Sample 9869: input length = 10
# Sample 9870: input length = 11
# Sample 9871: input length = 12
# Sample 9872: input length = 10
# Sample 9873: input length = 12
# Sample 9874: input length = 12
# Sample 9875: input length = 11
# Sample 9876: input length = 10
# Sample 9877: input length = 11
# Sample 9878: input length = 12
# Sample 9879: input length = 12
# Sample 9880: input length = 12
# Sample 9881: input length = 11
# Sample 9882: input length = 12
# Sample 9883: input length = 10
# Sample 9884: input length = 10
# Sample 9885: input length = 12
# Sample 9886: input length = 11
# Sample 9887: input length = 10
# Sample 9888: input length = 9
# Sample 9889: input length = 11
# Sample 9890: input length = 11
# Sample 9891: input length = 11
# Sample 9892: input length = 12
# Sample 9893: input length = 10
# Sample 9894: input length = 10
# Sample 9895: input length = 11
# Sample 9896: input length = 10
# Sample 9897: input length = 9
# Sample 9898: input length = 11
# Sample 9899: input length = 10
# Sample 9900: input length = 12
# Sample 9901: input length = 10
# Sample 9902: input length = 9
# Sample 9903: input length = 11
# Sample 9904: input length = 11
# Sample 9905: input length = 12
# Sample 9906: input length = 10
# Sample 9907: input length = 10
# Sample 9908: input length = 11
# Sample 9909: input length = 10
# Sample 9910: input length = 10
# Sample 9911: input length = 11
# Sample 9912: input length = 10
# Sample 9913: input length = 11
# Sample 9914: input length = 12
# Sample 9915: input length = 11
# Sample 9916: input length = 9
# Sample 9917: input length = 11
# Sample 9918: input length = 11
# Sample 9919: input length = 6
# Sample 9920: input length = 12
# Sample 9921: input length = 10
# Sample 9922: input length = 12
# Sample 9923: input length = 11
# Sample 9924: input length = 11
# Sample 9925: input length = 12
# Sample 9926: input length = 12
# Sample 9927: input length = 11
# Sample 9928: input length = 10
# Sample 9929: input length = 11
# Sample 9930: input length = 9
# Sample 9931: input length = 10
# Sample 9932: input length = 10
# Sample 9933: input length = 10
# Sample 9934: input length = 10
# Sample 9935: input length = 11
# Sample 9936: input length = 12
# Sample 9937: input length = 11
# Sample 9938: input length = 11
# Sample 9939: input length = 12
# Sample 9940: input length = 11
# Sample 9941: input length = 12
# Sample 9942: input length = 11
# Sample 9943: input length = 10
# Sample 9944: input length = 11
# Sample 9945: input length = 12
# Sample 9946: input length = 13
# Sample 9947: input length = 11
# Sample 9948: input length = 12
# Sample 9949: input length = 9
# Sample 9950: input length = 11
# Sample 9951: input length = 12
# Sample 9952: input length = 10
# Sample 9953: input length = 11
# Sample 9954: input length = 10
# Sample 9955: input length = 10
# Sample 9956: input length = 11
# Sample 9957: input length = 12
# Sample 9958: input length = 12
# Sample 9959: input length = 12
# Sample 9960: input length = 10
# Sample 9961: input length = 12
# Sample 9962: input length = 10
# Sample 9963: input length = 11
# Sample 9964: input length = 11
# Sample 9965: input length = 12
# Sample 9966: input length = 10
# Sample 9967: input length = 10
# Sample 9968: input length = 10
# Sample 9969: input length = 9
# Sample 9970: input length = 9
# Sample 9971: input length = 9
# Sample 9972: input length = 9
# Sample 9973: input length = 10
# Sample 9974: input length = 12
# Sample 9975: input length = 10
# Sample 9976: input length = 11
# Sample 9977: input length = 12
# Sample 9978: input length = 12
# Sample 9979: input length = 8
# Sample 9980: input length = 12
# Sample 9981: input length = 12
# Sample 9982: input length = 10
# Sample 9983: input length = 11
# Sample 9984: input length = 11
# Sample 9985: input length = 11
# Sample 9986: input length = 10
# Sample 9987: input length = 11
# Sample 9988: input length = 11
# Sample 9989: input length = 12
# Sample 9990: input length = 11
# Sample 9991: input length = 10
# Sample 9992: input length = 12
# Sample 9993: input length = 9
# Sample 9994: input length = 9
# Sample 9995: input length = 9
# Sample 9996: input length = 10
# Sample 9997: input length = 11
# Sample 9998: input length = 13
# Sample 9999: input length = 11

# %%
for i in range(10):
    print(tokenized_dataset['train'][i]['input_ids'])
# Out:
# [3, 18, 2555, 2294, 4906, 910, 2313, 507, 2668, 4327, 943, 2313, 1]
# [3, 4525, 3539, 4542, 910, 2313, 314, 14574, 943, 2313, 1]
# [3, 4608, 4327, 335, 2313, 220, 2773, 2517, 910, 2313, 1]
# [1283, 3390, 519, 910, 2313, 3, 4613, 4013, 943, 2313, 1]
# [3, 18, 2688, 2128, 4271, 910, 2313, 8798, 23360, 944, 2313, 1]
# [3, 18, 10402, 3288, 910, 2313, 3479, 4177, 460, 2313, 1]
# [3, 5947, 3840, 536, 460, 2313, 1902, 26225, 910, 2313, 1]
# [3, 6832, 4389, 4560, 910, 2313, 505, 27025, 944, 2313, 1]
# [668, 2606, 2658, 910, 2313, 3, 4591, 943, 2313, 1]
# [6374, 1828, 519, 910, 2313, 5400, 25312, 943, 2313, 1]
